# %% [markdown]
# <a href="https://colab.research.google.com/github/aini43325018-ui/2025_algoritma_dan_pemrograman/blob/Penugasan-Bab-E/Jobsheet_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01: Menghitung Luas Persegi Panjang

# %%
p = int(input("Masukkan panjang"))
l = int(input("Masukkan lebar:"))
luas = p * l
print("Luas persegi panjang*", luas)
# Out:
# Masukkan panjang10
# Masukkan lebar:10
# Luas persegi panjang* 100

# %% [markdown]
# Praktikum 02: Menghitung Luas Segitiga (Rumus Heron)

# %%
import math
a = float(input("Masukkan sisi a:"))
b = float(input("Masukkan sisi b:"))
c = float(input("Masukkan sisi c:"))
s = (a + b + c) / 2
luas = math.sqrt(s*(s-a)*(s-b)*(s-c))
print("Luas segitiga =", luas)
# Out:
# Masukkan sisi a:3
# Masukkan sisi b:4
# Masukkan sisi c:5
# Luas segitiga = 6.0

# %% [markdown]
# Praktikum 03: Konversi Suhu Celcius ke Fahrenheit

# %%
c = float(input("Masukkan suhu (°C)"))
f = (c * 9/5) + 32
print("Hasil konversi =", f, "°F")
# Out:
# Masukkan suhu (°C)32
# Hasil konversi = 89.6 °F

# %% [markdown]
# Praktikum 04. Menghitung Umur Berdasarkan Tahun Lahir

# %%
tahun_lahir = int(input("Masukkan tahun lahir:"))
tahun_sekarang = 2025
umur = tahun_sekarang - tahun_lahir
print ("Umur anda =", umur, "tahun")
# Out:
# Masukkan tahun lahir:2006
# Umur anda = 19 tahun

# %% [markdown]
# Praktikum 05: Menghitung Luas Lingkaran

# %%
import math
r = float(input("Masukkan jari-jari lingkaran:"))
luas = math.pi * r * r
print("Luas lingkaran =", luas)
# Out:
# Masukkan jari-jari lingkaran:14
# Luas lingkaran = 615.7521601035994

# %% [markdown]
# Praktikum 06: Menjumlahkan Tiga Bilangan

# %%
a = int(input("Masukkan bilangan pertama:"))
b = int(input("Masukkan bilangan kedua:"))
c = int(input("Masukkan bilangan ketiga:"))
jumlah = a + b + c
print("Jumlah=", jumlah)
# Out:
# Masukkan bilangan pertama:2
# Masukkan bilangan kedua:7
# Masukkan bilangan ketiga:2
# Jumlah= 11

# %% [markdown]
# Penugasan 01. Menghitung Volume Balok

# %%
panjang = float(input("Masukkan panjang balok"))
lebar = float(input("Masukkan lebar balok"))
tinggi = float(input("Masukkan tinggi balok"))

volume = panjang * lebar * tinggi

print("Volume Balok adalah:", volume)
# Out:
# Masukkan panjang balok2
# Masukkan lebar balok5
# Masukkan tinggi balok3
# Volume Balok adalah: 30.0

# %% [markdown]
# Penugasan 02. Konversi Waktu (Detik ke Jam:Menit:Detik)

# %%
totalDetik = int(input("Masukkan detik:"))
sisaDetik = totalDetik % 60
menit = totalDetik // 60
detik = sisaDetik % 60
jam = totalDetik // 3600
menit = menit % 60

print("Konversi Waktu dari", totalDetik,"detik adalah",jam,"jam",menit,"menit",sisaDetik,"detik")
# Out:
# Masukkan detik:250
# Konversi Waktu dari 250 detik adalah 0 jam 4 menit 10 detik

# %% [markdown]
# Penugasan 03. Rata-rata Nilai Tiga Mata Kuliah

# %%
a = float(input("Nilai Mata Kuliah 1 :"))
b = float(input("Nilai Mata Kuliah 2 :"))
c = float(input("Nilai Mata Kuliah 3 :"))
rataRata = ( a + b + c) / 3
if rataRata>= 60:
    keterangan = "Lulus"
else :
    keterangan = "Tidak Lulus"
print("Rata-rata Nilai Anda :", rataRata)
print("Keterangan", keterangan)
# Out:
# Nilai Mata Kuliah 1 :90
# Nilai Mata Kuliah 2 :100
# Nilai Mata Kuliah 3 :95
# Rata-rata Nilai Anda : 95.0
# Keterangan Lulus

# %% [markdown]
# Penugasan 04. Menghitung Diskon Belanja

# %%
total_belanja = float(input("Masukkan total belanja: "))

if total_belanja >= 500000:
    diskon = 0.20
elif total_belanja >= 250000:
    diskon = 0.10
else:
    diskon = 0.0

total_bayar = total_belanja - (total_belanja * diskon)

print(f"Total belanja: Rp{total_belanja:,.2f}")
print(f"Diskon yang didapat: {diskon * 100:.0f}%")
print(f"Total yang harus dibayar: Rp{total_bayar:,.2f}")
# Out:
# Masukkan total belanja: 500000
# Total belanja: Rp500,000.00
# Diskon yang didapat: 20%
# Total yang harus dibayar: Rp400,000.00
