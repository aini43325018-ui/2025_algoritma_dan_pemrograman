# %% [markdown]
# <a href="https://colab.research.google.com/github/aini43325018-ui/2025_algoritma_dan_pemrograman/blob/Penugasan-Bab-E/Praktikum%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01 - Pengenalan Variabel dan Tipe Data

# %%
#Integer
umur = 18
print("Umur:", umur, "→", type(umur))
print()

#Float
tinggi = 155.8
print("Tinggi:", tinggi, "→", type(tinggi))
print()

#String
nama = "Aini"
print("Nama:", nama, "→", type(nama))
print()

#Boolean
Real_or_fake = True
print("Real_or_fake", Real_or_fake, "→", type(Real_or_fake))
print()

#List
nilai = [80, 85, 90]
print("Nilai:", nilai, "→", type(nilai))
print()

#Tuple
koordinat = (10, 20)
print("Koordinat:", koordinat, "→", type(koordinat))
print()

#Dictionary
mahasiswa = {"nama": "Aini", "umur": 18, "prodi": "TRK"}
print("Data Mahasiswa:", mahasiswa, "→", type(mahasiswa))
print()

#Set
hobi = {"membaca", "olahraga", "musik"}
print("Hobi:", hobi, "→", type(hobi))
print()
# Out:
# Umur: 18 → <class 'int'>
#
# Tinggi: 155.8 → <class 'float'>
#
# Nama: Aini → <class 'str'>
#
# Real_or_fake True → <class 'bool'>
#
# Nilai: [80, 85, 90] → <class 'list'>
#
# Koordinat: (10, 20) → <class 'tuple'>
#
# Data Mahasiswa: {'nama': 'Aini', 'umur': 18, 'prodi': 'TRK'} → <class 'dict'>
#
# Hobi: {'olahraga', 'membaca', 'musik'} → <class 'set'>

# %% [markdown]
# Praktikum 02 - Input dan Output Dasar

# %%
#Input string
nama = input("Masukkan nama Anda:")

#Input integer
umur = int(input("Masukkan umur Anda:"))

#Input float
tinggi = float(input("Masukkan tinggi badan (cm): "))

#Output standar
print("Halo,", nama, "umur Anda:", umur, "tahun, tinggi:", tinggi, "cm")

#Output dengan format()
print("Halo {0}, umur Anda {1} tahun, tinggi {2} cm". format(nama, umur, tinggi))

#Output dengan f-string
print(f"Halo {nama}, umur Anda {umur} tahun, tinggi {tinggi} cm")
# Out:
# Masukkan nama Anda:Aini
# Masukkan umur Anda:18
# Masukkan tinggi badan (cm): 155
# Halo, Aini umur Anda: 18 tahun, tinggi: 155.0 cm
# Halo Aini, umur Anda 18 tahun, tinggi 155.0 cm
# Halo Aini, umur Anda 18 tahun, tinggi 155.0 cm

# %% [markdown]
# Praktikum 03 - Operator Aritmatika

# %%
a = 12
b = 2

print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
print("a // b =", a // b)
print("a % b =", a % b)
print("a ** b =", a **b)
# Out:
# a + b = 14
# a - b = 10
# a * b = 24
# a / b = 6.0
# a // b = 6
# a % b = 0
# a ** b = 144

# %% [markdown]
# Praktikum 04 - Operator Relasional

# %%
x = 10
y = 20

print("x == y :", x == y)
print("x !=y :", x != y)
print("x < y :", x < y)
print("x > y :", x > y)
print("x <= y :", x <= y)
print("x >= y :", x >=y)
# Out:
# x == y : False
# x !=y : True
# x < y : True
# x > y : False
# x <= y : True
# x >= y : False

# %% [markdown]
# Praktikum 05 - Operator Logika dengan Studi Kasus Nyata

# %%
# Operator logika dasar
a = True
b = False

# print("a and b =", a and b)
# print("a or b =", a or b)
# print("not a =", not a)

# Studi kasus nyata: kelulusan
nilai = int(input("Masukkan nilai ujian: "))
hadir = int(input("Masukkan jumlah kehadiran: "))

lulus_nilai = nilai >= 60
lulus_hadir = hadir >= 12 # dari 16 pertemuan

if lulus_nilai and lulus_hadir:
    print("Status: LULUS")
else:
    print("Status: TIDAK LULUS")
# Out:
# Masukkan nilai ujian: 98
# Masukkan jumlah kehadiran: 24
# Status: LULUS

# %% [markdown]
# Praktikum 06 - Program Kasir Sederhana

# %%
barang = input("Masukkan nama barang: ")
harga = float(input("Masukkan harga barang:"))
jumlah = int(input("Masukkan jumlah barang"))

total = harga * jumlah

# Aturan diskon
if total >= 500000:
    diskon = 0.2
elif total >= 250000:
    diskon = 0.1
else:
    diskon = 0

potongan = total * diskon
bayar = total - potongan

print("\n===== Struktur Belanja =====")
print(f"Barang : {barang}")
print(f"Jumlah : {jumlah}")
print(f"Total : Rp {total}")
print(f"Diskon : {diskon * 100}%")
print(f"Bayar : Rp {bayar}")
# Out:
# Masukkan nama barang: Photo card
# Masukkan harga barang:500000
# Masukkan jumlah barang2
#
# ===== Struktur Belanja =====
# Barang : Photo card
# Jumlah : 2
# Total : Rp 1000000.0
# Diskon : 20.0%
# Bayar : Rp 800000.0

# %% [markdown]
# Penugasan 1 - Identitas Mahasiswa

# %%
nama = input("Masukkan nama anda: ")
umur = int(input("Masukkan umur anda: "))
tinggi = float(input("Masukkan tinggi anda: "))
status = True

print("")
print(f"Selamat Datang {nama} \nUmur Anda Adalah {umur} tahun\nTinggi Anda {tinggi} cm \nStatus Mahasiswa {status}")
# Out:
# Masukkan nama anda: Aini
# Masukkan umur anda: 18
# Masukkan tinggi anda: 155
#
# Selamat Datang Aini
# Umur Anda Adalah 18 tahun
# Tinggi Anda 155.0 cm
# Status Mahasiswa True

# %% [markdown]
# Penugasan 2 - Operasi Aritmatika

# %%
a = int(input("Angka pertama: "))
b = int(input("Angka kedua:"))

penjumlahan = int(a + b)
pengurangan = int(a - b)
perkalian = int(a * b)
pembagian = int(a / b)
sisa_bagi = int(a % b)
pangkat = int(a ** b)

print()
print(f"Penjumlahan {a} dan {b} adalah {penjumlahan}")
print()
print(f"Pengurangan {a} dan {b} adalah {pengurangan}")
print()
print(f"Perkalian {a} dan {b} adalah {perkalian}")
print()
print(f"Pembagian {a} dan {b} adalah {pembagian}")
print()
print(f"Hasil dari sisa pembagian dari {a} dan {b} adalah {sisa_bagi}")
print()
print(f"Hasil perpangkatan {a} dan {b} adalah {pangkat}")
# Out:
# Angka pertama: 2
# Angka kedua:4
#
# Penjumlahan 2 dan 4 adalah 6
#
# Pengurangan 2 dan 4 adalah -2
#
# Perkalian 2 dan 4 adalah 8
#
# Pembagian 2 dan 4 adalah 0
#
# Hasil dari sisa pembagian dari 2 dan 4 adalah 2
#
# Hasil perpangkatan 2 dan 4 adalah 16

# %% [markdown]
# Penugasan 3 - Konversi Nilai

# %%
angka = float(input("Masukkan angka anda: "))
print()

a = int(angka)
b = str(angka)
c = round(angka, 2)

print(f"Bentuk integer dari {angka} adalah {a}")
print(f"Bentuk string dari {angka} adalah '{b}'")
print(f"Bentuk pembulatan 2 digit di belakang koma dari {angka} adalah {c}")
# Out:
# Masukkan angka anda: 93
#
# Bentuk integer dari 93.0 adalah 93
# Bentuk string dari 93.0 adalah '93.0'
# Bentuk pembulatan 2 digit di belakang koma dari 93.0 adalah 93.0

# %% [markdown]
# Penugasan 4 - Operator Relasional

# %%
a = int(input("Masukkan angka pertama: "))
b = int(input("Masukkan angka kedua: "))
print()

# if a >= b:
#   print(f"{a} >= {b}")
# elif a == b:
#   print(f"{a} == {b}")
# elif a != b:
#   print(f"{a} != {b}")
# elif a <= b:
#   print(f"{a} <= {b}")
# elif a < b:
#   print(f"{a} < {b}")
# else:
#   print(f"{a} > {b}")

print("a == b :", a == b)
print("a != b :", a != b)
print("a >= b :", a >= b)
print("a <= b :", a <= b)
print("a > b :", a > b)
print("a < b :", a < b)
# Out:
# Masukkan angka pertama: 34
# Masukkan angka kedua: 65
#
# a == b : False
# a != b : True
# a >= b : False
# a <= b : True
# a > b : False
# a < b : True
