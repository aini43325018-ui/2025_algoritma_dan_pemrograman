# %% [markdown]
# <a href="https://colab.research.google.com/github/aini43325018-ui/2025_algoritma_dan_pemrograman/blob/Penugasan-Bab-E/Jobsheet_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01 - If Sederhana

# %%
nilai = int(input("Masukkan nilai ujian: "))
if nilai >= 60:
  print("Anda LULUS")
# Out:
# Masukkan nilai ujian: 70
# Anda LULUS

# %% [markdown]
# Praktikum 02 - If-Else

# %%
nilai = int(input("Masukkan nilai ujian: "))
if nilai >= 60:
  print("Anda LULUS")
else:
  print("Anda TIDAK LULUS")
# Out:
# Masukkan nilai ujian: 50
# Anda TIDAK LULUS

# %% [markdown]
# Praktikum 03 - If-Elif-Else

# %%
nilai = int(input("Masukkan nilai akhir: "))

if nilai >= 85:
  grade = "A"
elif nilai >= 70:
  grade = "B"
elif nilai >= 55:
  grade = "C"
elif nilai >= 40:
  grade = "D"
else:
  grade = "E"

print(f"Nilai Anda {nilai}, maka grade Anda = {grade}")
# Out:
# Masukkan nilai akhir: 78
# Nilai Anda 78, maka grade Anda = B

# %% [markdown]
# Praktikum 04 - Nested If

# %%
ipk = float(input("Masukkan IPK: "))
sks = int(input("Masukkan jumlah SKS: "))

if ipk >= 3.0:
  if sks >= 18:
    print ("Anda LAYAK mendapat beasiswa")
  else:
    print("IPK memenuhi, tapi SKS kurang")
else:
  print("Anda TIDAK layak mendapat beasiswa")
# Out:
# Masukkan IPK: 2.8
# Masukkan jumlah SKS: 20
# Anda TIDAK layak mendapat beasiswa

# %% [markdown]
# Praktikum 05 - Match Case

# %%
menu = int(input("Pilih menu (1-3): "))

match menu:
  case 1:
    print("Anda memilih menu 1")
  case 2:
    print("Anda memilih menu 2")
  case 3:
    print("Anda memilih menu 3")
  case _:
    print("Menu tidak tersedia")
# Out:
# Pilih menu (1-3): 9
# Menu tidak tersedia

# %% [markdown]
# Praktikum 06 - Studi Kasus: Program Kasir

# %%
barang = input("Masukkan nama barang:")
harga = float(input("Masukkan harga barang: "))
jumlah = int(input("Masukkan jumlah barang: "))

total = harga * jumlah

if total >= 500000:
  diskon = 0.2
elif total >= 250000:
  diskon = 0.1
else:
  diskon = 0

bayar = total - (total * diskon)

print("\n===== Struk Belanja =====")
print(f"Barang: {barang}")
print(f"Jumlah : {jumlah}")
print(f"Total : Rp {total}")
print(f"Diskon : {diskon*100}%")
print(f"Bayar : Rp {bayar}")
# Out:
# Masukkan nama barang:Pulpen
# Masukkan harga barang: 5000
# Masukkan jumlah barang: 10
#
# ===== Struk Belanja =====
# Barang: Pulpen
# Jumlah : 10
# Total : Rp 50000.0
# Diskon : 0%
# Bayar : Rp 50000.0

# %% [markdown]
# Penugasan 1 - Cek Bilangan Positif/Negatif/Nol

# %%
# Meminta input dari pengguna
angka = int(input("Masukkan sebuah bilangan bulat"))

# Mengecek kondisi bilangan
if angka > 0:
  print("Bilangan tersebut adalah positif.")
elif angka < 0:
  print("Bilangan tersebut adalah negatif.")
else:
  print("Bilangan tersebut adalah nol.")
# Out:
# Masukkan sebuah bilangan bulat2
# Bilangan tersebut adalah positif.

# %% [markdown]
# Penugasan 2 - Menentukan Kategori Usia

# %%
# Meminta input umur dari pengguna
umur = int(input("Masukkan umur Anda: "))

# Menentukan kategori usia
if umur < 5:
  print("Kategori: Balita")
elif umur <= 11:
  print("Kategori: Anak-anak")
elif umur <=17:
  print("Kategori: Remaja")
elif umur <= 59:
  print("Kategori: Dewasa")
else:
  print("Kategori: Lansia")
# Out:
# Masukkan umur Anda: 18
# Kategori: Dewasa

# %% [markdown]
# Penugasan 3 - Hitung Tarif Parkir

# %%
# Meminta input durasi parkir dari pengguna dalam jam
durasi_parkir = int(input("Masukkan durasi parkir (dalam jam): "))

# Menghitung tarif parkir
if durasi_parkir <= 2:
  tarif = 5000
else:
  # Tarif untuk jam-jam berikutnya
  tarif = 5000 + (durasi_parkir - 2) * 2000

#Menerapkan tarif maksimal
if tarif > 20000:
    tarif = 20000

print(f"Tarif parkir Anda adalah: Rp {tarif}")
# Out:
# Masukkan durasi parkir (dalam jam): 3
# Tarif parkir Anda adalah: Rp 7000

# %% [markdown]
# Praktikum 4 - Cek Login Sederhana

# %%
# Meminta input username dan password dari pengguna
username = input("Masukkan username: ")
password = input("Masukkan password")

# Mengecek username dan password
if username == "admin" and password == "1234":
  print("Login berhasil")
else:
  print("Login gagal")
# Out:
# Masukkan username: admin
# Masukkan password1234
# Login berhasil

# %% [markdown]
# Penugasan 5 - One-Liner If (Cek Genap/Ganjil)

# %%
angka = int(input("Masukkan sebuah bilangan bulat: "))

hasil = "Genap" if angka % 2 == 0 else "Ganjil"

print(f"Bilangan {angka} adalah {hasil}")
# Out:
# Masukkan sebuah bilangan bulat: 2
# Bilangan 2 adalah Genap

# %% [markdown]
# Penugasan 6 - Menu Restoran dengan Match-Case

# %%
# Meminta input pilihan menu dari pengguna
menu = int(input("Pilihan menu (1-3): "))

# Menampilkan menu berdasarkan pilihan menggunakan match-case
match menu:
  case 1:
    print("Anda memilih Nasi Goreng")
  case 2:
    print("Anda memilih Mie Ayam")
  case 3:
    print("Anda memilih Soto Ayam")
  case _:
    print("Menu tidak tersedia")
# Out:
# Pilihan menu (1-3): 4
# Menu tidak tersedia

# %% [markdown]
# Penugasan 7 - Studi Kasus Nyata - Penetuan Diskon

# %%
# Meminta input nama barang, harga, dan jumlah
barang = input("Masukkan nama barang: ")
harga = float(input("Masukkan harga barang: "))
jumlah = int(input("Masukkan jumlah barang: "))

# Menghitung total belanja
total = harga * jumlah

# Menentukan diskon berdasarkan total belanja
if total >= 500000:
  diskon = 0.2
elif total >= 250000:
  diskon = 0.1
else:
  diskon = 0

# Menghitung jumlah bayar setelah diskon
bayar = total - (total * diskon)

print("\n===== Struk Belanja =====")
print(f"Barang : {barang}")
print(f"Jumlah : {jumlah}")
print(f"Total  : Rp {total}")
print(f"Diskon : {diskon*100}%")
print(f"Bayar  : Rp {bayar}")
# Out:
# Masukkan nama barang: Shampoo
# Masukkan harga barang: 25000
# Masukkan jumlah barang: 2
#
# ===== Struk Belanja =====
# Barang : Shampoo
# Jumlah : 2
# Total  : Rp 50000.0
# Diskon : 0%
# Bayar  : Rp 50000.0
