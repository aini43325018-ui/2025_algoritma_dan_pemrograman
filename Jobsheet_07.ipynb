# %% [markdown]
# <a href="https://colab.research.google.com/github/aini43325018-ui/2025_algoritma_dan_pemrograman/blob/Penugasan-Bab-E/Jobsheet_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01 - Tuple: Data Tetap yang Tidak Bisa Diubah

# %%
koordinat = (7.05, 110.44)
print("Lintang:", koordinat[0])
print("Bujur:", koordinat[1])
# Out:
# Lintang: 7.05
# Bujur: 110.44

# %% [markdown]
# Praktikum 02 - Dictionary Dasar: Menyimpan Data Mahasiswa

# %%
mahasiswa = {
    "NIM": "20251001",
    "Nama": "Andi",
    "Prodi": "TRK"
}

print("NIM :", mahasiswa["NIM"])
print("Nama:", mahasiswa["Nama"])
print("Prodi:", mahasiswa["Prodi"])
# Out:
# NIM : 20251001
# Nama: Andi
# Prodi: TRK

# %% [markdown]
# Praktikum 03 - Operasi pada Dictionary

# %%
mahasiswa = {
    "NIM": "20251001",
    "Nama": "Andi",
    "Prodi": "TRK"
}

mahasiswa["Umur"] = 20          # menambah data
mahasiswa["Prodi"] = "Teknik Komputer"  # memperbarui data
del mahasiswa["Umur"]           # menghapus data

print(mahasiswa)
# Out:
# {'NIM': '20251001', 'Nama': 'Andi', 'Prodi': 'Teknik Komputer'}

# %% [markdown]
# Praktikum 04 - Set dan Operasi Himpunan

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print("Union:", A | B)
print("Intersection:", A & B)
print("Difference:", A - B)
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference: {1, 2}

# %% [markdown]
# Praktikum 05 - Studi Kasus: Data Mahasiswa dan Mata Kuliah

# %%
mhs1 = {"Algoritma", "Matematika", "Bahasa Inggris"}
mhs2 = {"Algoritma", "Basis Data", "Matematika"}

print("Mata kuliah Mhs1:", mhs1)
print("Mata kuliah Mhs2:", mhs2)
print("Mata kuliah yang sama:", mhs1 & mhs2)
# Out:
# Mata kuliah Mhs1: {'Bahasa Inggris', 'Matematika', 'Algoritma'}
# Mata kuliah Mhs2: {'Matematika', 'Algoritma', 'Basis Data'}
# Mata kuliah yang sama: {'Matematika', 'Algoritma'}

# %% [markdown]
# Praktikum 06 - Studi Kasus Dictionary: Daftar Nilai Mahasiswa

# %%
nilai_mahasiswa = {
    "Andi": 80,
    "Budi": 75,
    "Cici": 90
}

for nama, nilai in nilai_mahasiswa.items():
    print(f"{nama}: {nilai}")

rata = sum(nilai_mahasiswa.values()) / len(nilai_mahasiswa)
print(f"Rata-rata nilai: {rata:.2f}")
# Out:
# Andi: 80
# Budi: 75
# Cici: 90
# Rata-rata nilai: 81.67

# %% [markdown]
# Penugasan 01 - Tuple Sederhana

# %%
mahasiswa = ("Aini", 20, "Teknik Komputer")
print("Nama :", mahasiswa[0])
print("Umur :", mahasiswa[1])
print("Prodi :", mahasiswa[2])

print("\n---")
# Out:
# Nama : Aini
# Umur : 20
# Prodi : Teknik Komputer
#
# ---

# %% [markdown]
# Penugasan 02 - Tuple Tidak Bisa Diubah

# %%
angka = (1, 1, 3)

# Mencoba mengubah elemen pertama
print("Sebelum diubah:", angka)

# Baris berikut akan menyebabkan error
data[0] = 10

print("Setelah diubah:", angka)
# Out:
# Sebelum diubah: (1, 1, 3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4019285417.py in <cell line: 0>()
#       5
#       6 # Baris berikut akan menyebabkan error
# ----> 7 data[0] = 10
#       8
#       9 print("Setelah diubah:", angka)
#
# NameError: name 'data' is not defined

# %% [markdown]
# Penugasan 03 - Dictionary Dasar

# %%
buku = {"Judul": "Algoritma", "Penulis": "Munir", "Tahun": 2021}
print("Judul  :", buku["Judul"])
print("Penulis:", buku["Penulis"])
print("Tahun  :", buku["Tahun"])

print("\n---")
# Out:
# Judul  : Algoritma
# Penulis: Munir
# Tahun  : 2021
#
# ---

# %% [markdown]
# Penugasan 04 - Operasi Dictionary

# %%
dosen = {"NIP": "12345", "Nama": "Budi", "Prodi": "TRK"}
dosen["Umur"] = 40                        # Tambah key Umur
dosen["Prodi"] = "Teknik Komputer"        # Perbarui Prodi
del dosen["Umur"]                         # Hapus key Umur
print("Data dosen akhir:", dosen)

print("\n---")
# Out:
# Data dosen akhir: {'NIP': '12345', 'Nama': 'Budi', 'Prodi': 'Teknik Komputer'}
#
# ---

# %% [markdown]
# Penugasan 05 - Set dan Himpunan

# %%
A = {"Matematika", "Algoritma", "Bahasa Inggris"}
B = {"Algoritma", "Basis Data", "Matematika"}
print("Union        :", A | B)
print("Intersection :", A & B)
print("Difference   :", A - B)

print("\n---")
# Out:
# Union        : {'Bahasa Inggris', 'Basis Data', 'Matematika', 'Algoritma'}
# Intersection : {'Matematika', 'Algoritma'}
# Difference   : {'Bahasa Inggris'}
#
# ---

# %% [markdown]
# Penugasan 06 - Studi Kasus Dictionary

# %%
nilai = {"Andi": 85, "Budi": 90, "Cici": 78}
print("Daftar nilai mahasiswa:")
for nama, n in nilai.items():
  print(f"{nama}: {n}")

rata_rata = sum(nilai.values()) / len(nilai)
print("Rata-rata nilai:", rata_rata)

print("\n---")
# Out:
# Daftar nilai mahasiswa:
# Andi: 85
# Budi: 90
# Cici: 78
# Rata-rata nilai: 84.33333333333333
#
# ---

# %% [markdown]
# Penugasan 07 - Studi Kasus Set - Klub Mahasiswa

# %%
klub_A = {"Andi", "Budi", "Cici"}
klub_B = {"Cici", "Deni", "Eka"}

print("Seluruh anggota (union):", klub_A | klub_B)
print("Anggota di kedua klub (intersection):", klub_A & klub_B)
print("Hanya di Klub A (difference):", klub_A - klub_B)
# Out:
# Seluruh anggota (union): {'Budi', 'Eka', 'Cici', 'Deni', 'Andi'}
# Anggota di kedua klub (intersection): {'Cici'}
# Hanya di Klub A (difference): {'Andi', 'Budi'}
