# %% [markdown]
# <a href="https://colab.research.google.com/github/aini43325018-ui/2025_algoritma_dan_pemrograman/blob/Penugasan-Bab-E/Jobsheet_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01 - Indexing dan Slicing

# %%
teks = "Politeknik Negeri Semarang"
print(teks[0])      # 'P'
print(teks[0:11])   # 'Politeknik'
print(teks[-8:])    # 'Semarang'
# Out:
# P
# Politeknik
# Semarang

# %% [markdown]
# Praktikum 02 - Method Bawaan String

# %%
teks = " Politeknik Negeri Semarang "
print(teks.upper())
print(teks.lower())
print(teks.title())
print(teks.strip())
print(teks.split(" "))
print("-".join(["Politeknik","Negeri","Semarang"]))
# Out:
#  POLITEKNIK NEGERI SEMARANG
#  politeknik negeri semarang
#  Politeknik Negeri Semarang
# Politeknik Negeri Semarang
# ['', 'Politeknik', 'Negeri', 'Semarang', '']
# Politeknik-Negeri-Semarang

# %% [markdown]
# Praktikum 03 - Validasi Password

# %%
password = input ("Masukkan password: ")

if len(password) >= 8:
  print("Password valid")
else:
  print("Password terlalu pendek")
# Out:
# Masukkan password: abc
# Password terlalu pendek

# %% [markdown]
# Praktikum 04 - String Formatting dengan F-String

# %%
nama = input("Masukkan nama: ")
umur = int(input("Masukkan umur: "))

print(f"Nama saya {nama}, umur {umur} tahun.")
# Out:
# Masukkan nama: Budi
# Masukkan umur: 21
# Nama saya Budi, umur 21 tahun.

# %% [markdown]
# Praktikum 05 - Operasi dalam F-String

# %%
a = int(input("Masukkan nilai a: "))
b = int(input("Masukkan nilai b: "))

print(f"Hasil penjumlahan {a}+{b} = {a+b}")
print(f"Hasil pembagian {a}/{b} = {a/b:.2f}")
# Out:
# Masukkan nilai a: 10
# Masukkan nilai b: 3
# Hasil penjumlahan 10+3 = 13
# Hasil pembagian 10/3 = 3.33

# %% [markdown]
# Praktikum 06 - Casting String

# %%
angka = 123
teks = "456"

print("Nilai: " + str(angka))
print(int(teks) + 10)
# Out:
# Nilai: 123
# 466

# %% [markdown]
# Praktikum 07 - Studi Kasus Nyata: Analisis Kalimat

# %%
kalimat = "Saya kuliah di Politeknik Negeri Semarang"
daftar_kata = kalimat.split(" ")

print(f"Jumlah kata: {len(daftar_kata)}")
for i, kata in enumerate(daftar_kata, start=1):
  print(i, kata)
# Out:
# Jumlah kata: 6
# 1 Saya
# 2 kuliah
# 3 di
# 4 Politeknik
# 5 Negeri
# 6 Semarang

# %% [markdown]
# Penugasan 01 - Indexing dan Slicing

# %%
teks = "Politeknik Negeri Semarang"

# Huruf pertama
print("Huruf pertama:", teks[0])

# Huruf terakhir
print("Huruf terakhir:", teks[-1])

# Kata "Negeri" menggunakan slicing
print("Kata 'Negeri':", teks[12:18])
# Out:
# Huruf pertama: P
# Huruf terakhir: g
# Kata 'Negeri': egeri

# %% [markdown]
# Penugasan 02 - Manipulasi String

# %%
kalimat = input("Masukkan kalimat:")

print("Huruf kapital :", kalimat.upper())
print("Huruf kecil   :", kalimat.lower())
print("Panjang kalimat:", len(kalimat))
# Out:
# Masukkan kalimat:Zayn Malik
# Huruf kapital : ZAYN MALIK
# Huruf kecil   : zayn malik
# Panjang kalimat: 10

# %% [markdown]
# Penugasan 03 - Validasi Username

# %%
username = input("Masukkan username: ")

if " " in username:
  print("Error: Username tidak boleh mengandung spasi!")
else:
  print("Username valid.")
# Out:
# Masukkan username: ainoyz
# Username valid.

# %% [markdown]
# Penugasan 04 - String Formatting dengan F-String

# %%
nama = input("Nama: ")
umur = input("Umur: ")
jurusan = input("Jurusan: ")

print(f"\nNama {nama}")
print(f"Umur: {umur}")
print(f"Jurusan: {jurusan}")
# Out:
# Nama: Aini
# Umur: 18
# Jurusan: Teknik Elektro
#
# Nama Aini
# Umur: 18
# Jurusan: Teknik Elektro

# %% [markdown]
# Penugasan 05 - Operasi dalam F-String

# %%
a = float(input("Masukkan bilangan pertama:  "))
b = float(input("Masukkan bilangan kedua: "))

print(f"Penjumlahan: {a +  b}")
print(f"Perkalian: {a * b}")
print(f"Pembagian: {(a / b):.3f}")
# Out:
# Masukkan bilangan pertama:  2
# Masukkan bilangan kedua: 7
# Penjumlahan: 9.0
# Perkalian: 14.0
# Pembagian: 0.286

# %% [markdown]
# Penugasan 06 - Casting Data

# %%
angka_str = input("Masukkan angka (string): ")

# ubah ke integer
angka_int = int(angka_str)
print(f"Kuadrat dari {angka_int} adalah {angka_int ** 2}")

# ubah ke float
angka_float = float(angka_str)
print(f"Angka dalam format float: {angka_float:.2f}")
# Out:
# Masukkan angka (string): 5
# Kuadrat dari 5 adalah 25
# Angka dalam format float: 5.00

# %% [markdown]
# Penugasan 07 - Studi Kasus: Analisis Teks

# %%
kalimat = input("Masukkan kalimat: ")

# Pisahkan kata-kata
kata_list = kalimat.split()

# Hitung jumlah kata
jumlah_kata = len(kata_list)

# Temukan kata terpanjang
kata_terpanjang = max(kata_list, key=len)

# Urutkan kata-kata
kata_urut = sorted(kata_list)

print(f"\nJumlah kata: {jumlah_kata}")
print(f"Kata terpanjang: {kata_terpanjang}")
print("Kata dalam urutan abjad:", kata_urut)
# Out:
# Masukkan kalimat: Kapan EXO comeback?
#
# Jumlah kata: 3
# Kata terpanjang: comeback?
# Kata dalam urutan abjad: ['EXO', 'Kapan', 'comeback?']
